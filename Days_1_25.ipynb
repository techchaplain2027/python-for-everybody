# %% [markdown]
# <a href="https://colab.research.google.com/github/techchaplain2027/python-for-everybody/blob/main/Days_1_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
# Out:
# Hello, Python!
